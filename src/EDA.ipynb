# %%
import pandas as pd

# %% [markdown]
# # Load and preview data

# %%
df = pd.read_csv("/home/moraa-ontita/Documents/Machine-learning/talent_survey/data/Technology_Access_and_Adoption_Survey_2023.csv")
# Out:
# /tmp/ipykernel_169745/1943199113.py:1: DtypeWarning: Columns (108,195,254,279,288) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/home/moraa-ontita/Documents/Machine-learning/talent_survey/data/Technology_Access_and_Adoption_Survey_2023.csv")

# %%
df.head()
# Out:
#        ID  samplegroup  SurveyLanguage  Q1  Q2r1  Q2r2  Q2r3  Q2r4  Q2r5  \
# 0  100044            1               1   1     0     1     0     0     0
# 1  100158            3               3   1     0     1     0     0     0
# 2  100192            3               1   1     1     0     0     0     0
# 3  100339            2               3   1     0     0     0     0     1
# 4  100869            3               1   1     1     0     0     0     0
#
#    Q2r6  ...  securityskills  collabskills  fullskills  q15summarygroups  \
# 0     0  ...               1             1           1                 2
# 1     0  ...               2             2           2                 1
# 2     0  ...               1             1           1                 4
# 3     0  ...               2             2           2                 1
# 4     0  ...               1             1           1                 3
#
#    DigitalOpportunityScore  Device  Access  Skills  WEIGHT_HH  WEIGHT_INDIV
# 0                        0       0       0       0   0.010000      0.010000
# 1                        1       0       1       1   0.135922      0.569338
# 2                        1       0       2       0   1.394373      3.697548
# 3                        2       1       2       1   0.820729      0.342130
# 4                        1       0       1       0   0.310458      0.549847
#
# [5 rows x 327 columns]

# %%
df.shape
# Out:
# (4197, 327)

# %%
import os

# Define the path to the root directory from the notebook (one level up from src/)
root_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
artifacts_dir = os.path.join(root_dir, "artifacts", "eda")

# Create the directory if it doesn't exist
os.makedirs(artifacts_dir, exist_ok=True)

# Define the file path for output
file_path = os.path.join(artifacts_dir, "column_names.txt")

# Write all column names to the file
with open(file_path, "w") as f:
    for i, col in enumerate(df.columns):
        f.write(f"{i+1}. {col}\n")

print(f"Column names saved to: {file_path}")
# Out:
# Column names saved to: /home/moraa-ontita/Documents/Machine-learning/talent_survey/artifacts/eda/column_names.txt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4197 entries, 0 to 4196
# Columns: 327 entries, ID to WEIGHT_INDIV
# dtypes: float64(169), int64(145), object(13)
# memory usage: 10.5+ MB

# %% [markdown]
# # Checking for missing Values

# %%
# Count missing values per column
missing_values = df.isnull().sum()

# Filter columns with missing values
missing_values_filtered = missing_values[missing_values > 0]

# Display the result
print("Columns with missing values:\n")
print(missing_values_filtered)

# Total number of such columns
print(f"\nNumber of columns with missing values: {missing_values_filtered.shape[0]}")

# Total number of missing values across the dataset
print(f"Total missing values in the dataset: {missing_values_filtered.sum()}")
# Out:
# Columns with missing values:
#
# Q3                3
# Q4HaveSum        33
# Q4OwnSum         33
# Q4BorrowSum      33
# Q4r1c1           33
#                ...
# Q41            4138
# ZIPCode         140
# Tract           163
# CD               90
# RSEindex        163
# Length: 180, dtype: int64
#
# Number of columns with missing values: 180
# Total missing values in the dataset: 197579

# %%
# Count missing values per column
missing_values = df.isnull().sum()

# Calculate percentage of missing values per column
missing_percent = (missing_values / len(df)) * 100

# Filter columns with more than 40% missing values
high_missing = missing_percent[missing_percent > 40]

# Display the result
print("Columns with more than 40% missing data:\n")
print(high_missing.sort_values(ascending=False))

# Total number of such columns
print(f"\nNumber of columns with >40% missing values: {high_missing.shape[0]}")
# Out:
# Columns with more than 40% missing data:
#
# Q30r4oe           99.761735
# q14r8oe           99.166071
# Q41               98.594234
# q26r10oe          98.284489
# Q36r9             97.903264
# q34r6oe           97.807958
# Q35r3oe           97.736478
# Q38r10oe          97.522040
# Q5Ar5oe           97.188468
# Q5Br5c1           97.116988
# Q33r7oe           96.807243
# Q36r8oe           96.402192
# Q5Cr5             96.235406
# q9r5oe            95.878008
# q13r9oe           95.878008
# Q5Br3c1           93.066476
# Q5Cr3             92.208721
# q19r11oe          91.017393
# Q28r6c1           78.198713
# Q28r1c1           76.078151
# Q28r2c1           75.291875
# Q28r4c1           73.266619
# Q28r5c1           72.242078
# Q28r3c1           71.813200
# Q5Br1c1           71.122230
# Q5Cr1             70.216822
# Q28br5c4          63.712175
# Q28br2c4          63.712175
# Q28br1c4          63.712175
# Q28br3c4          63.712175
# Q28br4c4          63.712175
# Q28br6c4          63.712175
# noanswerQ4_r5     63.211818
# Q15ar20           63.211818
# Child4to17HH      62.687634
# noanswerQ29_r2    62.592328
# Q14r1             62.473195
# Q14r2             62.473195
# Q14r6             62.473195
# Q14r8             62.473195
# Q14r7             62.473195
# Q14r5             62.473195
# Q14r3             62.473195
# Q14r4             62.473195
# Q14r10            62.473195
# Q35A              58.970693
# Q19r11            53.800334
# Q5Ar4oe           44.841553
# Q5Br4c1           44.793900
# Q5Br2c1           44.770074
# Q5Cr4             43.936145
# Q5Cr2             43.888492
# dtype: float64
#
# Number of columns with >40% missing values: 52
